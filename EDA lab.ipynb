# %%
import pandas as pd

# %%
# read our CSV file into a dataframe
df = pd.read_csv('HR_dataset.csv')
df
# Out:
#                   names  satisfaction_level  last_evaluation  number_project  \
# 0        Jessica Stroud                0.38             0.53               2
# 1          Daryl Fields                0.80             0.86               5
# 2        Daisy Anderson                0.11             0.88               7
# 3      Joseph Fernandez                0.72             0.87               5
# 4         Herbert Moore                0.37             0.52               2
# ...                 ...                 ...              ...             ...
# 14995        Roger King                0.37             0.48               2
# 14996         Ora Lyles                0.37             0.53               2
# 14997   Steven Freedman                0.11             0.96               6
# 14998  Randall Williams                0.37             0.52               2
# 14999    Bessie Coleman                0.82             0.91               5
#
# ...

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        15000.000000     15000.000000    15000.000000
# mean             0.612847         0.716115        3.803133
# std              0.248628         0.171171        1.232590
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_monthly_hours  exp_in_company  work_accident          left  \
# count           15000.000000    15000.000000   15000.000000  15000.000000
# mean              201.052400        3.498333       0.144600      0.238133
# std                49.942074        1.460139       0.351709      0.425955
# min                96.000000        2.000000       0.000000      0.000000
# ...

# %%
df.describe().T
# Out:
#                          count        mean        std    min     25%     50%  \
# satisfaction_level     15000.0    0.612847   0.248628   0.09    0.44    0.64
# last_evaluation        15000.0    0.716115   0.171171   0.36    0.56    0.72
# number_project         15000.0    3.803133   1.232590   2.00    3.00    4.00
# average_monthly_hours  15000.0  201.052400  49.942074  96.00  156.00  200.00
# exp_in_company         15000.0    3.498333   1.460139   2.00    3.00    3.00
# work_accident          15000.0    0.144600   0.351709   0.00    0.00    0.00
# left                   15000.0    0.238133   0.425955   0.00    0.00    0.00
# promotion_last_5years  15000.0    0.021267   0.144277   0.00    0.00    0.00
#
#                           75%    max
# satisfaction_level       0.82    1.0
# last_evaluation          0.87    1.0
# number_project           5.00    7.0
# average_monthly_hours  245.00  310.0
# exp_in_company           4.00   10.0
# work_accident            0.00    1.0
# ...

# %% [markdown]
# count all tally (15000) so no missing values
# 75% of the entire population satisfaction level is 0.82 very high

# %%
# correlation study

corr = df.corr(numeric_only=True)
corr
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105077       -0.142908
# last_evaluation                  0.105077         1.000000        0.349380
# number_project                  -0.142908         0.349380        1.000000
# average_monthly_hours           -0.020013         0.339770        0.417232
# exp_in_company                  -0.100803         0.131658        0.196839
# work_accident                    0.058673        -0.007135       -0.004767
# left                            -0.388225         0.006701        0.023900
# promotion_last_5years            0.025596        -0.008695       -0.006073
#
#                        average_monthly_hours  exp_in_company  work_accident  \
# satisfaction_level                 -0.020013       -0.100803       0.058673
# last_evaluation                     0.339770        0.131658      -0.007135
# ...

# %% [markdown]
# # business question
# 1. what is the reason somebody leave the company  (- target variable: left)
#
# positive corr (up, up)
#
# negative corr (down, up)

# %%
# prompt: generate a heatmap for corr

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # correlation doesn't mean causation

# %%
# prompt: draw a plot that shows how many people left vs how many people stay group by their num_project

import matplotlib.pyplot as plt

# Group by 'number_project' and 'left' and count the number of employees
project_left_counts = df.groupby(['number_project', 'left'])['left'].count().unstack()

# Plot the counts
project_left_counts.plot(kind='bar', figsize=(10, 6))
plt.title('Number of Employees Left vs. Stayed by Number of Projects')
plt.xlabel('Number of Projects')
plt.ylabel('Number of Employees')
plt.legend(['Stayed', 'Left'])
plt.show()

# %% [markdown]
# for 2 projects, most people leave
# for 3-5 projects is sweet spot, most people stay
# for 6-7, most people left bcs they overwork cannot tahan

# %%
# prompt: draw a plot that shows the effect of salary on left

# Group by 'salary' and 'left' and count the number of employees
salary_left_counts = df.groupby(['salary', 'left'])['left'].count().unstack()

# Plot the counts
salary_left_counts.plot(kind='bar', figsize=(10, 6))
plt.title('Number of Employees Left vs. Stayed by Salary')
plt.xlabel('Salary Level')
plt.ylabel('Number of Employees')
plt.legend(['Stayed', 'Left'])
plt.show()

# %%
# prompt: draw a plot that shows attrition group by role

# Group by 'sales' and 'left' and count the number of employees
role_left_counts = df.groupby(['role', 'left'])['left'].count().unstack()

# Plot the counts
role_left_counts.plot(kind='bar', figsize=(10, 6))
plt.title('Number of Employees Left vs. Stayed by Role')
plt.xlabel('Role')
plt.ylabel('Number of Employees')
plt.legend(['Stayed', 'Left'])
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# prompt: draw a plot that shows the left based on their satisfaction level using histogram

plt.figure(figsize=(10, 6))
plt.hist(df[df['left'] == 1]['satisfaction_level'], bins=20, alpha=0.5, label='Left')
plt.hist(df[df['left'] == 0]['satisfaction_level'], bins=20, alpha=0.5, label='Stayed')
plt.xlabel('Satisfaction Level')
plt.ylabel('Number of Employees')
plt.title('Histogram of Satisfaction Level for Employees who Left vs. Stayed')
plt.legend()
plt.show()

# %%
sns.displot(data=df, x="satisfaction_level",hue="left",binwidth=0.1)

# %%
sns.displot(data=df, x="satisfaction_level",hue="left",binwidth=0.2,multiple="stack")

# %% [markdown]
# # Car Sales Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/theleadio/datascience_demo/master/car_sales.csv")
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  Resale_value Vehicle_type  \
# 0          Acura  Integra              16.919        16.360    Passenger
# 1          Acura       TL              39.384        19.875    Passenger
# 2          Acura       CL              14.114        18.225    Passenger
# 3          Acura       RL               8.588        29.725    Passenger
# 4           Audi       A4              20.397        22.255    Passenger
# ..           ...      ...                 ...           ...          ...
# 152        Volvo      V40               3.545           NaN    Passenger
# 153        Volvo      S70              15.245           NaN    Passenger
# 154        Volvo      V70              17.531           NaN    Passenger
# 155        Volvo      C70               3.493           NaN    Passenger
# 156        Volvo      S80              18.969           NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
df.describe()
# Out:
#        Sales_in_thousands  Resale_value  Price_in_thousands  Engine_size  \
# count          157.000000    121.000000          155.000000   156.000000
# mean            52.998076     18.072975           27.390755     3.060897
# std             68.029422     11.453384           14.351653     1.044653
# min              0.110000      5.160000            9.235000     1.000000
# 25%             14.114000     11.260000           18.017500     2.300000
# 50%             29.450000     14.180000           22.799000     3.000000
# 75%             67.956000     19.875000           31.947500     3.575000
# max            540.561000     67.550000           85.500000     8.000000
#
#        Horsepower   Wheelbase       Width      Length  Curb_weight  \
# count  156.000000  156.000000  156.000000  156.000000   155.000000
# mean   185.948718  107.487179   71.150000  187.343590     3.378026
# std     56.700321    7.641303    3.451872   13.431754     0.630502
# ...

# %%
df.describe().T
# Out:
#                     count        mean        std         min         25%  \
# Sales_in_thousands  157.0   52.998076  68.029422    0.110000   14.114000
# Resale_value        121.0   18.072975  11.453384    5.160000   11.260000
# Price_in_thousands  155.0   27.390755  14.351653    9.235000   18.017500
# Engine_size         156.0    3.060897   1.044653    1.000000    2.300000
# Horsepower          156.0  185.948718  56.700321   55.000000  149.500000
# Wheelbase           156.0  107.487179   7.641303   92.600000  103.000000
# Width               156.0   71.150000   3.451872   62.600000   68.400000
# Length              156.0  187.343590  13.431754  149.400000  177.575000
# Curb_weight         155.0    3.378026   0.630502    1.895000    2.971000
# Fuel_capacity       156.0   17.951923   3.887921   10.300000   15.800000
# Fuel_efficiency     154.0   23.844156   4.282706   15.000000   21.000000
# Power_perf_factor   155.0   77.043591  25.142664   23.276272   60.407707
#
# ...

# %% [markdown]
# business question: know the selling price and factors that affect the price

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#                     Sales_in_thousands  Resale_value  Price_in_thousands  \
# Sales_in_thousands            1.000000     -0.279034           -0.304734
# Resale_value                 -0.279034      1.000000            0.953840
# Price_in_thousands           -0.304734      0.953840            1.000000
# Engine_size                   0.019983      0.531330            0.626875
# Horsepower                   -0.197756      0.769081            0.839744
# Wheelbase                     0.358179     -0.052270            0.110513
# Width                         0.140918      0.178767            0.329136
# Length                        0.254980      0.026548            0.156935
# Curb_weight                   0.008628      0.361557            0.526224
# Fuel_capacity                 0.086540      0.325567            0.423282
# Fuel_efficiency              -0.016764     -0.399880           -0.492157
# Power_perf_factor            -0.223252      0.827123            0.897945
#
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
# prompt: draw a heatmap using seaborn for corr

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# prompt: visualise the relationship between car manufacture and price

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(x='Manufacturer', y='Price_in_thousands', data=df)
plt.title('Relationship Between Car Manufacturer and Price')
plt.xlabel('Manufacturer')
plt.ylabel('Price')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# prompt: visualise the relationship between car manufacturer and price_in_thousands, turn the label 90 degrees, using a vibrant bright palette, draw the chart in HD, hide the future warnigns

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 10), dpi=300)  # Increased figure size and DPI for HD
sns.boxplot(x='Manufacturer', y='Price_in_thousands', data=df, palette='bright')
plt.title('Relationship Between Car Manufacturer and Price')
plt.xlabel('Manufacturer')
plt.ylabel('Price (in thousands)')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()  # Ensures labels don't overlap
plt.show()

# %% [markdown]
# The illustration shows the relationship between various car manufacturers and their prices, displayed in thousands of dollars.
#
# - X-axis (Manufacturer): Different car brands such as Acura, Audi, BMW
# - Y-axis (Prices in Thousands): The price of the cars from each manufacturer, shown in thousands of dollars.
# - Box-plots: Each box plot represents the distribution of prices for a specific manufacturer, showing the median, quartiles, and potential outliers.
#     - The line inside each box represents the median price for that manufacturer.
#     - The end of the box represents the 25th and 75th precentiles.
#     - The 'whiskers' extend to the smallest and largest values, excluding outliers
#     - Any outliers (points outside the typical range) are marked as circles.
#
#   These visualisation helps compares the price ranges of different car brands. For instance, manufacturers like Mercedes-Benz, Porsche, and Lexus tend to have higher price ranges compared to brands like Saturn, Volkwagens, and Hyundai. Outliers for brands like Chevrolet, Cadillac, and Subaru show visually high or low prices for certain models.

# %%
sns.pairplot(df)

# %% [markdown]
# can check the linear relationship
