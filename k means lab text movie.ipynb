# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/theleadio/datascience_demo/refs/heads/master/movie_overview.csv')

# %%
df
# Out:
#           id                        title  \
# 0          0                    Toy Story
# 1          1                      Jumanji
# 2          2             Grumpier Old Men
# 3          3            Waiting to Exhale
# 4          4  Father of the Bride Part II
# ...      ...                          ...
# 45461  45461                       Subdue
# 45462  45462          Century of Birthing
# 45463  45463                     Betrayal
# 45464  45464             Satan Triumphant
# 45465  45465                     Queerama
#
#                                                 overview
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# ...

# %%
# prompt: turn df['overview'] into unicode

df['overview'] = df['overview'].astype("U")

# %%
# prompt: clustering the movie for df['overview']

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Create a TfidfVectorizer object
vectorizer = TfidfVectorizer(stop_words='english')

# Fit and transform the 'overview' column
tfidf_matrix = vectorizer.fit_transform(df['overview'])

# Perform KMeans clustering
num_clusters = 5  # You can adjust the number of clusters
kmeans = KMeans(n_clusters=num_clusters, random_state=0)
kmeans.fit(tfidf_matrix)

# Add the cluster labels to the DataFrame
df['cluster'] = kmeans.labels_

# Print the results (optional)
for i in range(5):
    print(f"Cluster {i}:")
    print(df[df['cluster'] == i]['title'].tolist())
    print("\n")
# Out:
# Cluster 0:
# ...

# %%
import matplotlib.pyplot as plt

inertias = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(tfidf_matrix)
    inertias.append(kmeans.inertia_)

plt.plot(range(1, 11), inertias, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
# prompt: clustering the movie for df['overview']

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Create a TfidfVectorizer object
vectorizer = TfidfVectorizer(stop_words='english')

# Fit and transform the 'overview' column
tfidf_matrix = vectorizer.fit_transform(df['overview'])

# Perform KMeans clustering
num_clusters = 5  # You can adjust the number of clusters
kmeans = KMeans(n_clusters=num_clusters, random_state=0)
kmeans.fit(tfidf_matrix)

# Add the cluster labels to the DataFrame
df['cluster'] = kmeans.labels_

# Print the results (optional)
# Out:
# Cluster 0:
# ...

# %%
for i in range(6):
    print(f"Cluster {i+1}:")
    print(df[df['cluster'] == i]['title'].tolist())
    print("\n")
# Out:
# Cluster 1:
# ...

# %%
# prompt: draw a word cloud for cluster 1

from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Get the text for cluster 1
cluster1_overviews = df[df['cluster'] == 0]['overview'].tolist()

# Combine all overviews into a single string
text = ' '.join(cluster1_overviews)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the generated image:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for Cluster 1")
plt.show()

# %%
# prompt: draw a word cloud for cluster 1

from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Get the text for cluster 1
cluster_overviews = df[df['cluster'] == 2]['overview'].tolist()

# Combine all overviews into a single string
text = ' '.join(cluster_overviews)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the generated image:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for Cluster 1")
plt.show()

# %% [markdown]
# Linear regression model
# - R Square : relative measure how good the model feeds the variable where mean square error is absolute measure
# - mean square error : to calculate errors/ square to counter effects of negative
# - elbow method : calculate distance
# - silhouette
# - confusion matrix
