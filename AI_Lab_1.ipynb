# %% [markdown]
# <a href="https://colab.research.google.com/github/pangtengg/mcmc/blob/main/AI_Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
api_key = ' '

# %%
# !pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.9 MB/s eta 0:00:00
# ...

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key)

# %%
stream = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "user",
         "content": "Please help me to write a pantun about Malaysia"}
        ],
    stream=True,
)

for chunk in stream:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="")
# Out:
# Certainly! A pantun is a traditional Malay poem, consisting of a quatrain with an ABAB rhyme scheme. Here’s a pantun about Malaysia:
#
# Di tepi pantai pohon kelapa,
# Angin laut membawa rasa;
# Negaraku indah berseri rupa,
# Malaysia tercinta penuh budaya.
#
# If you have any specific themes or ideas you would like included, feel free to let me know!

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key)

stream = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role":"system", "content": "You are a CMO in a listed company"},
        {"role": "user", "content": "Please give me a framework to apply AI in marketing campaigns"}
        ],
    stream=True,
)

for chunk in stream:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="")
# Out:
# Implementing AI in marketing campaigns can significantly enhance efficiency, targeting, and overall effectiveness. Below is a structured framework that you can follow to apply AI in your marketing initiatives:
#
# ### AI in Marketing Framework
#
# #### 1. **Define Objectives**
#    - **Set Clear Goals**: Determine what you want to achieve with AI (e.g., improve customer engagement, optimize ad spend, enhance personalization).
#    - **Identify KPIs**: Establish key performance indicators to measure success (e.g., CTR, conversion rates, customer lifetime value).
#
# #### 2. **Understand Your Data**
#    - **Data Collection**: Gather relevant data from various sources (e.g., CRM systems, social media, website analytics).
#    - **Data Quality Assessment**: Evaluate the quality, relevance, and completeness of your data.
#    - **Data Segmentation**: Segment your audience based on demographics, behavior, and interests.
#
# #### 3. **Choose the Right AI Tools**
# ...

# %% [markdown]
# Implementing AI in marketing campaigns can significantly enhance efficiency, targeting, and overall effectiveness. Below is a structured framework that you can follow to apply AI in your marketing initiatives:
#
# ### AI in Marketing Framework
#
# #### 1. **Define Objectives**
#    - **Set Clear Goals**: Determine what you want to achieve with AI (e.g., improve customer engagement, optimize ad spend, enhance personalization).
#    - **Identify KPIs**: Establish key performance indicators to measure success (e.g., CTR, conversion rates, customer lifetime value).
#
# #### 2. **Understand Your Data**
#    - **Data Collection**: Gather relevant data from various sources (e.g., CRM systems, social media, website analytics).
#    - **Data Quality Assessment**: Evaluate the quality, relevance, and completeness of your data.
#    - **Data Segmentation**: Segment your audience based on demographics, behavior, and interests.
#
# #### 3. **Choose the Right AI Tools**
#    - **AI-Powered Analytics**: Use predictive analytics tools to forecast trends and consumer behavior.
#    - **Chatbots and Virtual Assistants**: Implement AI chatbots for customer service and engagement.
#    - **Personalization Engines**: Leverage AI algorithms to deliver personalized content and recommendations.
#    - **Ad Optimization Platforms**: Utilize machine learning tools for programmatic advertising and audience targeting.
#
# #### 4. **Develop AI Models**
#    - **Select Algorithms**: Choose appropriate algorithms based on your objectives (e.g., regression for forecasting, clustering for segmentation).
#    - **Data Training**: Train models with historical data to recognize patterns and make predictions.
#    - **Test and Validate**: Maintain a test set to validate model performance before full deployment.
#
# #### 5. **Integration into Campaigns**
#    - **Automate Campaigns**: Use AI for automating email marketing, social media posting, and other repetitive tasks.
#    - **Dynamic Content**: Implement real-time data to adjust content and offers according to user interactions.
#    - **A/B Testing**: Use AI algorithms to run simultaneous tests and analyze results for continuous optimization.
#
# #### 6. **Monitor and Analyze Performance**
#    - **Real-Time Analytics**: Implement dashboards to monitor campaign performance in real time.
#    - **Performance Analysis**: Analyze the effectiveness of AI-driven tactics against set KPIs.
#    - **Feedback Loop**: Establish a feedback mechanism to continuously improve AI models based on campaign insights.
#
# #### 7. **Ethics and Compliance**
#    - **Transparency**: Ensure campaigns utilizing AI adhere to ethical guidelines and transparent practices.
#    - **Data Privacy**: Comply with regulations such as GDPR and CCPA regarding data collection and user consent.
#
# #### 8. **Scale Up**
#    - **Pilot Programs**: Start with smaller campaigns to test AI tools, then scale successful initiatives.
#    - **Cross-Functional Collaboration**: Work with IT, sales, and customer service teams to leverage AI insights across the organization.
#    - **Continuous Learning**: Stay updated on AI advancements and best practices to evolve campaigns.
#
# #### 9. **Evaluate ROI**
#    - **Return on Investment**: Calculate the ROI for AI-driven initiatives by comparing costs and revenue generated.
#    - **Strategic Adjustments**: Use insights gained from performance analysis to make data-informed decisions about future campaigns.
#
# ### Conclusion
#
# By following this framework, you can effectively harness the power of AI to optimize your marketing campaigns. This process allows for personalization at scale, more efficient allocation of resources, and better engagement with your audience. It's essential to stay adaptable and continuously refine your approach as technology and consumer behavior evolve.

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key)

stream = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role":"system", "content": "You are a head of digital marketing in a startup."},
        {"role": "user", "content": "Please give me a framework and budget plan to apply AI in marketing campaigns"}
        ],
    stream=True,
)

for chunk in stream:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="")
# Out:
# Implementing AI in marketing campaigns can greatly enhance efficiency, targeting, and personalization. Below is a framework outlining the key steps and considerations, alongside a budget plan to guide the integration of AI into your marketing strategies.
#
# ### Framework for Implementing AI in Marketing Campaigns
#
# 1. **Define Goals and Objectives**
#    - Identify what you want to achieve with AI (e.g., improve lead generation, optimize ad spend, enhance personalization).
#    - Set specific, measurable, achievable, relevant, and time-bound (SMART) objectives.
#
# 2. **Assess Current Capabilities**
#    - Evaluate existing marketing tools and systems.
#    - Analyze data quality and availability for AI training and implementation.
#    - Identify any skill gaps within your team.
#
# 3. **Select AI Tools and Technologies**
#    - Research and choose AI platforms (e.g., chatbots, predictive analytics, marketing automation) that fit your budget and needs.
# ...

# %% [markdown]
# ### Framework for Implementing AI in Marketing Campaigns
#
# 1. **Define Goals and Objectives**
#    - Identify what you want to achieve with AI (e.g., improve lead generation, optimize ad spend, enhance personalization).
#    - Set specific, measurable, achievable, relevant, and time-bound (SMART) objectives.
#
# 2. **Assess Current Capabilities**
#    - Evaluate existing marketing tools and systems.
#    - Analyze data quality and availability for AI training and implementation.
#    - Identify any skill gaps within your team.
#
# 3. **Select AI Tools and Technologies**
#    - Research and choose AI platforms (e.g., chatbots, predictive analytics, marketing automation) that fit your budget and needs.
#    - Consider third-party AI solutions (like Salesforce Einstein, HubSpot’s AI features, or Google Ads' Smart features) vs. in-house development.
#
# 4. **Develop Data Strategy**
#    - Create a plan for collecting, storing, and managing data to train AI models.
#    - Ensure compliance with data privacy regulations (e.g., GDPR, CCPA).
#
# 5. **Integration Plan**
#    - Establish how AI tools will integrate with existing marketing systems (CRM, email marketing platforms, social media).
#    - Define workflows and processes for campaign execution.
#
# 6. **Staff Training and Development**
#    - Train existing staff on using AI tools and interpreting AI-generated insights.
#    - Consider hiring new talent with expertise in AI and data analytics if necessary.
#
# 7. **Pilot Projects**
#    - Start with small-scale pilot projects to test the effectiveness of AI in specific areas.
#    - Gather data and insights from these pilots to drive adjustments and improvements.
#
# 8. **Analyze and Optimize**
#    - Continuously monitor campaign performance with AI-driven analytics.
#    - Use insights to make data-driven decisions and optimize future campaigns.
#
# 9. **Scale Up**
#    - Based on the results and learnings from pilot projects, scale successful AI applications across your marketing campaigns.
#
# 10. **Feedback Loop**
#     - Establish mechanisms for feedback and improvement.
#     - Regularly review AI tools and processes to ensure they meet evolving business goals.
#
# ### Budget Plan for AI Implementation in Marketing
#
# 1. **Initial Assessment and Research**
#    - **Budget:** $2,500 - $5,000
#    - Expenses for consulting services or workshops to evaluate needs and tools.
#
# 2. **AI Tools and Software**
#    - **Budget:** $5,000 - $20,000 per year
#    - Depending on the selected software; subscription-based services, including CRM integrations and marketing automation tools.
#
# 3. **Data Management and Storage**
#    - **Budget:** $1,000 - $3,000 per year
#    - Costs for cloud storage or database management systems to manage customer data.
#
# 4. **Training and Development**
#    - **Budget:** $2,000 - $5,000
#    - Workshops, online courses, or hiring trainers to upskill existing staff.
#
# 5. **Pilot Project Execution**
#    - **Budget:** $3,000 - $10,000
#    - Costs associated with running initial pilot campaigns (ad spend, content creation, A/B testing tools).
#
# 6. **Monitoring and Analytics Tools**
#    - **Budget:** $1,000 - $5,000 per year
#    - Investment in tools to track and analyze marketing performance (e.g., Google Analytics, data visualization tools).
#
# 7. **Maintenance and Continuous Learning**
#    - **Budget:** $1,500 - $4,000 per year
#    - Ongoing costs for updates, additional training, or subscription renewals.
#
# ### Total Estimated Budget: $16,000 - $52,000
#
# ### Conclusion
#
# This framework provides a structured approach to integrating AI into your marketing campaigns, focusing on the importance of strategy, tools, training, and performance analysis. The budget can be adjusted based on the size of your startup and the specific AI applications you choose to implement. As the technology and market evolve, staying up to date with the latest AI advancements and best practices will be key to leveraging AI effectively in your marketing efforts.

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key)

stream = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role":"system", "content": "You are an officer from JPN Malaysia"},
        {"role": "user", "content": "Please tell me if the name Lau Cher Han is a Chinese, Malay, or Indian"}
        ],
    stream=True,
)

for chunk in stream:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="")
# Out:
# The name Lau Cher Han is typically of Chinese origin. The surname "Lau" (also spelled "Lau," "Loh," or "Liew," depending on the dialect) is common among Chinese communities in Malaysia. The given names "Cher Han" also reflect Chinese naming conventions.

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key)

stream = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "Ceritakan satu lawak tentang Malaysian"}
        ],
    stream=True,
)

for chunk in stream:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="")
# Out:
# Tentu! Ini satu lawak tentang orang Malaysia:
#
# Suatu hari, seorang pelancong dari luar negara bertanya kepada seorang lelaki Malaysia, "Apa yang paling terkenal tentang Malaysia?"
#
# Lelaki itu tersenyum dan berkata, "Makanan kita, budaya kita, dan juga…"
#
# Pelancong itu menyambung, "Dan juga apa?"
#
# Lelaki itu menjawab, "Dan juga kemampuan kita untuk menunggu bas yang selalu lewat!"
#
# Pelancong itu terkejut dan bertanya, "Betulkah bas di sini selalu lewat?"
#
# Lelaki itu ketawa dan berkata, "Oh, bukan bas, tapi jawapan kami '5 minit lagi!'"
#
# Semoga gelak!

# %%
result = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role":"system", "content": "You are an expert in banking"},
        {"role": "user", "content": "Can you give me a list of questions to consider when picking a stock?"}
        ],
)

# %%
result
# Out:
# ChatCompletion(id='chatcmpl-AGcnf221KfYCmQ8qwO9jwflDDwZjm', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Certainly! When evaluating a stock for potential investment, it's crucial to ask a variety of questions that span company performance, market conditions, financial health, and future outlook. Here’s a list of questions to consider:\n\n### Company Fundamentals\n1. **What is the company's business model?** \n   - How does the company make money?\n   \n2. **What is the company's competitive advantage?** \n   - Does it have a strong brand, unique technology, or cost advantages?\n\n3. **What is the company’s revenue growth rate?** \n   - How has revenue grown over the past few years, and what are the projections?\n\n4. **What are the profit margins?** \n   - Are they improving, stable, or declining?\n\n5. **What is the company’s earnings history?**\n   - How consistently has the company met or exceeded earnings expectations?\n\n##
# ...

# %%
# prompt: print message from result, render the message as markdown

from IPython.display import Markdown

message = result.choices[0].message.content
Markdown(message)
# Out:
# Certainly! When evaluating a stock for potential investment, it's crucial to ask a variety of questions that span company performance, market conditions, financial health, and future outlook. Here’s a list of questions to consider:
#
# ### Company Fundamentals
# 1. **What is the company's business model?**
#    - How does the company make money?
#
# 2. **What is the company's competitive advantage?**
#    - Does it have a strong brand, unique technology, or cost advantages?
#
# 3. **What is the company’s revenue growth rate?**
#    - How has revenue grown over the past few years, and what are the projections?
#
# 4. **What are the profit margins?**
#    - Are they improving, stable, or declining?
#
# 5. **What is the company’s earnings history?**
#    - How consistently has the company met or exceeded earnings expectations?
#
# ### Financial Health
# 6. **What does the balance sheet look like?**
#    - Are there significant amounts of debt compared to equity?
#
# ...

# %%
from openai import OpenAI
import cv2
import time
import base64
import requests

# for colab camera
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode


class CameraApp:
    def __init__(self, camera_index, api_key):
        self.camera_index = camera_index
        self.api_key = api_key

    def initialize_camera(self):
        self.cap = cv2.VideoCapture(self.camera_index)
        if not self.cap.isOpened():
            print("Cannot open camera")
            return False
        return True

    # take photo in Google Colab:
    # https://colab.research.google.com/notebooks/snippets/advanced_outputs.ipynb#scrollTo=buJCl90WhNfq

    def take_photo(self, filename='photo.jpg', quality=0.8):
      js = Javascript('''
        async function takePhoto(quality) {
          const div = document.createElement('div');
          const capture = document.createElement('button');
          capture.textContent = 'Capture';
          div.appendChild(capture);

          const video = document.createElement('video');
          video.style.display = 'block';
          const stream = await navigator.mediaDevices.getUserMedia({video: true});

          document.body.appendChild(div);
          div.appendChild(video);
          video.srcObject = stream;
          await video.play();

          // Resize the output to fit the video element.
          google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

          // Wait for Capture to be clicked.
          await new Promise((resolve) => capture.onclick = resolve);

          const canvas = document.createElement('canvas');
          canvas.width = video.videoWidth;
          canvas.height = video.videoHeight;
          canvas.getContext('2d').drawImage(video, 0, 0);
          stream.getVideoTracks()[0].stop();
          div.remove();
          return canvas.toDataURL('image/jpeg', quality);
        }
        ''')
      display(js)
      data = eval_js('takePhoto({})'.format(quality))
      binary = b64decode(data.split(',')[1])
      with open(filename, 'wb') as f:
        f.write(binary)
      return filename

    def capture_image(self, filename='capture.jpg'):
        if not self.initialize_camera():
            return False
        time.sleep(2)  # Camera warm-up
        for _ in range(10): self.cap.read()  # Autoexposure adjustment
        ret, frame = self.cap.read()
        if ret:
            cv2.imwrite(filename, frame)
            print("Image captured successfully")
        else:
            print("Failed to capture image")
        self.cap.release()
        cv2.destroyAllWindows()
        return ret

    def encode_image(self, image_path):
        with open(image_path, "rb") as image_file:
            return base64.b64encode(image_file.read()).decode('utf-8')

    def send_request(self, image_data):
        headers = {"Content-Type": "application/json", "Authorization": f"Bearer {self.api_key}"}
        payload = {
            "model": "gpt-4-vision-preview",
            "messages": [{
                "role": "user",
                "content": [{"type": "text", "text": "Tell me about this image. Limit your response to 100 words."}, {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_data}"}}]
            }],
            "max_tokens": 300
        }
        return requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload).json()

    def save_response_as_audio(self, response_data, audio_output="output.mp3"):
        response = client.audio.speech.create(
            model="tts-1",
            voice="alloy",
            input=response_data['choices'][0]['message']['content'],
        )
        response.stream_to_file(audio_output)
        return response_data['choices'][0]['message']['content']

    def openai_api_calculate_cost(self, usage, model="gpt-4-1106-vision-preview"):
      pricing = {
          'gpt-3.5-turbo-1106': {
              'prompt': 0.001,
              'completion': 0.002,
          },
          'gpt-4-8k': {
              'prompt': 0.03,
              'completion': 0.06,
          },
          'gpt-4-32k': {
              'prompt': 0.06,
              'completion': 0.12,
          },
          'gpt-4-1106-vision-preview': {
              'prompt': 0.01,
              'completion': 0.03,
          }
      }

      try:
          model_pricing = pricing[model]
      except KeyError:
          raise ValueError("Invalid model specified")

      prompt_cost = usage['prompt_tokens'] * model_pricing['prompt'] / 1000
      completion_cost = usage['completion_tokens'] * model_pricing['completion'] / 1000

      total_cost = prompt_cost + completion_cost
      print(f"\nTokens used:  {usage['prompt_tokens']:,} prompt + {usage['completion_tokens']:,} completion = {usage['total_tokens']:,} tokens")
      print(f"Total cost for {model}: ${total_cost:.4f}\n")

      return total_cost

# %%
# Now, let run the application

from IPython.display import Audio
from IPython.display import display

camera_app = CameraApp(camera_index=1, api_key=client.api_key)
if camera_app.take_photo(filename='capture.jpg'):
    encoded_image = camera_app.encode_image('capture.jpg')
    response_data = camera_app.send_request(encoded_image)
    interpretation = camera_app.save_response_as_audio(response_data, audio_output="output.mp3")
    print("interpretation of the captured image:%s" % interpretation)
    total_cost = camera_app.openai_api_calculate_cost(response_data['usage'])

    wn = Audio("output.mp3", autoplay=True) ##
    display(wn)## play the audio
# Out:
# interpretation of the captured image:This image shows a person using a computer mouse while closely observing or interfacing with a robotic arm. In the background, there are two rectangular panels or canvas-like art pieces, one black, the other maroon, against a white wall. The setting could be within a workspace or lab where human-machine interaction is being demonstrated or tested. The focus is on the interaction between the person and the robotic equipment, possibly indicating work in robotics, automation, or human-computer interaction research.
#
# Tokens used:  446 prompt + 96 completion = 542 tokens
# Total cost for gpt-4-1106-vision-preview: $0.0073
# <ipython-input-23-a6e5ef06e0cd>:104: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   response.stream_to_file(audio_output)
#                 <audio  controls="controls" autoplay="autoplay">
# ...

# %%
from IPython.display import Image

response = client.images.generate(
  model="dall-e-3",
  prompt="a white siamese cat",
  size="1024x1024",
  quality="standard",
  n=1,
)

image_url = response.data[0].url


Image(url=image_url)
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-i9fozCk7g6hE2XScCR0gCDbi/user-nW1BfhVnOAk1YS9ux0uUys0P/img-2HvneUu9iGMP41Tfo1dvwwRo.png?st=2024-10-10T01%3A39%3A52Z&se=2024-10-10T03%3A39%3A52Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-10-09T22%3A37%3A02Z&ske=2024-10-10T22%3A37%3A02Z&sks=b&skv=2024-08-04&sig=x3W1V6BwyZPjxjvlA7HwxJOyT6zIigLDj0nRSDtqMbI%3D"/>
